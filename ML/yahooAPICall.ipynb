# %%
# !pip install yfinance
# !pip install yahoo_fin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 1.4 MB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 81 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 83 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 140 kB 46.1 MB/s
# ...
#      |████████████████████████████████| 106 kB 57.6 MB/s
# ...
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24590 sha256=63ce275226c6d40c8dfdc1f0648e5a15feeb059c1647c5565605091b1d0d23ca
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
# ...

# %%
#### stock_info methods:

#get_analysts_info()
#get_balance_sheet()
#get_cash_flow()
#get_data()
#get_day_gainers()        # UNUSABLE WITHOUT requests_html
#get_day_losers()         # UNUSABLE WITHOUT requests_html
#get_day_most_active()    # UNUSABLE WITHOUT requests_html
#get_holders()
#get_income_statement()
#get_live_price()
#get_quote_table()
#get_top_crypto()         # UNUSABLE WITHOUT requests_html
#get_stats()
#get_stats_valuation()
#tickers_dow()
#tickers_nasdaq()
#tickers_other()
#tickers_sp500()
#get_calls()
#get_expiration_dates()    # UNUSABLE WITHOUT requests_html
#get_options_chain()
#get_puts()

# %%
from yahoo_fin.stock_info import get_data

# get_data(ticker, start_date = None, end_date = None, index_as_date = True, interval = “1d”)

amazon_weekly= get_data("amzn", start_date="12/04/2009", end_date="12/04/2021", index_as_date = True, interval="1wk")
amazon_weekly
# Out:
#                   open        high         low       close    adjclose  \
# 2009-11-30    7.181000    7.295500    6.755500    6.879000    6.879000
# 2009-12-07    6.900000    6.950000    6.491000    6.707500    6.707500
# 2009-12-14    6.625000    6.630500    6.282500    6.424000    6.424000
# 2009-12-21    6.524000    6.985000    6.509500    6.923500    6.923500
# 2009-12-28    6.987500    7.129000    6.726000    6.726000    6.726000
# ...                ...         ...         ...         ...         ...
# 2021-11-01  168.089996  178.312500  164.177505  175.949493  175.949493
# 2021-11-08  176.162003  180.272507  172.352493  176.257507  176.257507
# 2021-11-15  176.850006  188.107498  176.257507  183.828506  183.828506
# 2021-11-22  183.819000  185.673004  175.207504  175.227997  175.227997
# 2021-11-29  177.382004  179.800003  166.929993  169.489502  169.489502
#
#                volume ticker
# 2009-11-30  627018000   AMZN
# 2009-12-07  957260000   AMZN
# ...

# %%
ticker_list = ["amzn", "aapl", "ba"]

historical_datas = {}
for ticker in ticker_list:
    historical_datas[ticker] = get_data(ticker)

# %%
historical_datas["aapl"]
# Out:
#                   open        high         low       close    adjclose  \
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099874
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094663
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087715
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089886
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092492
# ...                ...         ...         ...         ...         ...
# 2022-11-07  137.110001  139.149994  135.669998  138.919998  138.919998
# 2022-11-08  140.410004  141.429993  137.490005  139.500000  139.500000
# 2022-11-09  138.500000  138.550003  134.589996  134.869995  134.869995
# 2022-11-10  141.240005  146.869995  139.500000  146.869995  146.869995
# 2022-11-11  145.820007  150.009995  144.369995  149.699997  149.699997
#
#                volume ticker
# 1980-12-12  469033600   AAPL
# 1980-12-15  175884800   AAPL
# ...
